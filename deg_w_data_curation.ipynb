# %%
# !python main.py --data_curation True --config './OAI_config.json' --llm 'gpt-4o' --code_exec LocalCLI --human_input ALWAYS --logfile runtime.log
# Out:
# Logging session ID: 319cc09a-748a-4381-91ce-88b641f404d2
# ...
#   Using cached numpy-2.0.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# ...
#   Using cached scanpy-1.10.2-py3-none-any.whl.metadata (9.3 kB)
# ...
#   Using cached cellxgene_census-1.15.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached anndata-0.10.8-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached h5py-3.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached legacy_api_wrap-1.4-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
